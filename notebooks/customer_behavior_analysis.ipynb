# %% [markdown]
# # Customer Behavior Analytics
# This notebook demonstrates quick EDA and KPI checks on exported pipeline data.

# %%
import pandas as pd
df = pd.read_csv('../data/transactions_enriched.csv')
df.head()
